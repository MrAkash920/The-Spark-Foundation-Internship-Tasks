# %% [markdown]
# ## The Spark Foundation
#
# ### Aim: *Prediction Using Unsupervised Learning*
#
# Author: Akash SIngh
# github: https://github.com/MrAkash920/

# %% [markdown]
# ### **Unsupervised learning**
# Unsupervised Learning is a type of machine learning (ML) technique that uses artificial intelligence (AI) algorithms to identify patterns in data sets that are neither classified nor labeled.

# %% [markdown]
# Target: From the given 'Iris' dataset, predict the optimum number of clusters and represent it visually.
#
# To achive this target i will use K-Means clustering. To determine the optimum number of clusters in the Iris dataset and represent it visually, you can use the K-Means clustering algorithm. The Elbow Method is a common technique for finding the optimal number of clusters.

# %%
#import all required libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.datasets import load_iris

# %%
#Load dataset
data = load_iris()
X = pd.DataFrame(data.data, columns=data.feature_names)

# %% [markdown]
# Determine the optimal number of clusters using the Elbow Method

# %%
wcss = []  # Within-Cluster-Sum-of-Squares

for i in range(1, 11):
    kmeans = KMeans(n_clusters=i, init='k-means++', max_iter=300, n_init=10, random_state=0)
    kmeans.fit(X)
    wcss.append(kmeans.inertia_)

# Plot the Elbow Method graph
plt.figure(figsize=(6, 4))
plt.plot(range(1, 11), wcss, marker='o', linestyle='--')
plt.title('Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
plt.show()

# %% [markdown]
# Fit the K-Means model with the chosen number of clusters (3 in this case)

# %%
kmeans = KMeans(n_clusters=3, init='k-means++', max_iter=300, n_init=10, random_state=0)
kmeans.fit(X)
# Out:
# KMeans(n_clusters=3, n_init=10, random_state=0)

# %% [markdown]
# Visualize the clusters

# %%
plt.scatter(X['sepal length (cm)'], X['sepal width (cm)'], c=kmeans.labels_, cmap='rainbow')
plt.xlabel('Sepal Length')
plt.ylabel('Sepal Width')
plt.show()
